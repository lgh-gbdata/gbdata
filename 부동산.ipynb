# %% [markdown]
# <a href="https://colab.research.google.com/github/lgh-gbdata/gbdata/blob/main/%EB%B6%80%EB%8F%99%EC%82%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
with open('/gdrive/My Drive/foo.txt', 'w') as f:
  f.write('Hello Google Drive!')
# !cat '/gdrive/My Drive/foo.txt'
# Out:
# Hello Google Drive!

# %%
# prompt: 아래 데이터를 가지고 데이터가 어떠한 내용인지 분석하고 시각화 하는 내용을 스트림릿으로 작성해줘
# /content/drive/MyDrive/data/01_부동산/all_apartment_data(2023_2024_47).csv

# !pip install streamlit
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import streamlit as st
from google.colab import drive

# Google Drive 마운트
drive.mount('/content/drive') # Google Drive 마운트를 확실하게 실행

# Google Drive에서 데이터 불러오기
data_path = '/content/drive/MyDrive/data/01_부동산/all_apartment_data(2023_2024_47).csv'
# 파일 경로가 정확한지 다시 한번 확인

# 파일 경로가 정확한지 확인하기 위해 출력해보기
print(data_path)

try:
    df = pd.read_csv(data_path)
except FileNotFoundError:
    st.error("파일을 찾을 수 없습니다. 파일 경로를 확인해주세요.")
    st.stop() # 파일을 찾을 수 없으면 Streamlit 앱 실행 중지
except Exception as e:
    st.error(f"데이터를 불러오는 중 오류가 발생했습니다: {e}")
    st.stop() # 다른 오류 발생 시에도 Streamlit 앱 실행 중지

# Streamlit 앱 시작
st.title('부동산 데이터 분석')

# 데이터 정보 출력
st.header('데이터 정보')
st.write(df.head())
st.write(df.info())
st.write(df.describe())

# 시각화
st.header('데이터 시각화')

# 1. 지역별 평균 거래 가격
st.subheader('지역별 평균 거래 가격')
df['dealAmount'] = pd.to_numeric(df['dealAmount'].str.replace(',', ''), errors='coerce')

avg_price_by_region = df.groupby('sggCd')['dealAmount'].mean()
fig, ax = plt.subplots()
ax.bar(avg_price_by_region.index, avg_price_by_region.values)
plt.xlabel('지역')
plt.ylabel('평균 거래 가격')
st.pyplot(fig)

# # 2. 거래 유형별 거래 건수
# st.subheader('거래 유형별 거래 건수')
# transaction_type_counts = df['거래유형'].value_counts()
# fig, ax = plt.subplots()
# ax.pie(transaction_type_counts, labels=transaction_type_counts.index, autopct='%1.1f%%')
# st.pyplot(fig)

# 3. 거래 금액 분포
st.subheader('거래 금액 분포')
fig, ax = plt.subplots()
sns.histplot(df['dealAmount'], kde=True)
plt.xlabel('거래 금액')
plt.ylabel('빈도수')
st.pyplot(fig)

# 추가적인 분석 및 시각화를 원하는 경우 여기에 추가
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/data/01_부동산/all_apartment_data(2023_2024_47).csv
# 2024-10-09 16:13:25.231 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-09 16:13:25.233 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-09 16:13:25.235 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-09 16:13:25.237 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-09 16:13:25.249 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-09 16:13:25.255 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
# prompt: 위의 내용을 한글이 안꺠지도록 하고 그래프로 나타내줘

from google.colab import drive
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import streamlit as st
drive.mount('/gdrive')
with open('/gdrive/My Drive/foo.txt', 'w') as f:
  f.write('Hello Google Drive!')
# !cat '/gdrive/My Drive/foo.txt'

# !pip install streamlit
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn


# Google Drive 마운트
drive.mount('/content/drive') # Google Drive 마운트를 확실하게 실행

# Google Drive에서 데이터 불러오기
data_path = '/content/drive/MyDrive/data/01_부동산/all_apartment_data(2023_2024_47).csv'
# 파일 경로가 정확한지 다시 한번 확인

# 파일 경로가 정확한지 확인하기 위해 출력해보기
print(data_path)

try:
    df = pd.read_csv(data_path)
except FileNotFoundError:
    st.error("파일을 찾을 수 없습니다. 파일 경로를 확인해주세요.")
    st.stop() # 파일을 찾을 수 없으면 Streamlit 앱 실행 중지
except Exception as e:
    st.error(f"데이터를 불러오는 중 오류가 발생했습니다: {e}")
    st.stop() # 다른 오류 발생 시에도 Streamlit 앱 실행 중지

# Streamlit 앱 시작
st.title('부동산 데이터 분석')

# 데이터 정보 출력
st.header('데이터 정보')
st.write(df.head())
st.write(df.info())
st.write(df.describe())

# 시각화
st.header('데이터 시각화')




# 한글 폰트 설정 (Google Colab에서)
plt.rc('font', family='NanumBarunGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False # 마이너스 폰트 깨짐 방지

# 1. 지역별 평균 거래 가격
st.subheader('지역별 평균 거래 가격')
df['dealAmount'] = pd.to_numeric(df['dealAmount'].str.replace(',', ''), errors='coerce')

avg_price_by_region = df.groupby('sggCd')['dealAmount'].mean()
fig, ax = plt.subplots()
ax.bar(avg_price_by_region.index, avg_price_by_region.values)
plt.xlabel('지역')
plt.ylabel('평균 거래 가격')
st.pyplot(fig)



# 3. 거래 금액 분포
st.subheader('거래 금액 분포')
fig, ax = plt.subplots()
sns.histplot(df['dealAmount'], kde=True)
plt.xlabel('거래 금액')
plt.ylabel('빈도수')
st.pyplot(fig)

# 추가적인 분석 및 시각화를 원하는 경우 여기에 추가
# Out:
# Mounted at /gdrive
# Hello Google Drive!
# 2024-10-09 16:18:59.264 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-09 16:18:59.266 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-09 16:18:59.269 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-09 16:18:59.271 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# Mounted at /content/drive
# /content/drive/MyDrive/data/01_부동산/all_apartment_data(2023_2024_47).csv
# 2024-10-09 16:18:59.280 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-09 16:18:59.281 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
# prompt: 위의 내용을 실행하니 df.info 까지만 나오고 나머지는 안 나와

from google.colab import drive
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# !pip install streamlit
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn

# Google Drive 마운트
drive.mount('/content/drive') # Google Drive 마운트를 확실하게 실행

# Google Drive에서 데이터 불러오기
data_path = '/content/drive/MyDrive/data/01_부동산/all_apartment_data(2023_2024_47).csv'
# 파일 경로가 정확한지 다시 한번 확인

# 파일 경로가 정확한지 확인하기 위해 출력해보기
print(data_path)

try:
    df = pd.read_csv(data_path)
except FileNotFoundError:
    print("파일을 찾을 수 없습니다. 파일 경로를 확인해주세요.")
    # st.stop() # 파일을 찾을 수 없으면 Streamlit 앱 실행 중지
except Exception as e:
    print(f"데이터를 불러오는 중 오류가 발생했습니다: {e}")
    # st.stop() # 다른 오류 발생 시에도 Streamlit 앱 실행 중지


# 데이터 정보 출력
print('데이터 정보')
print(df.head())
print(df.info())
print(df.describe())

# 시각화
print('데이터 시각화')


# 한글 폰트 설정 (Google Colab에서)
plt.rc('font', family='NanumBarunGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False # 마이너스 폰트 깨짐 방지

# 1. 지역별 평균 거래 가격
print('지역별 평균 거래 가격')
df['dealAmount'] = pd.to_numeric(df['dealAmount'].str.replace(',', ''), errors='coerce')

avg_price_by_region = df.groupby('sggCd')['dealAmount'].mean()
fig, ax = plt.subplots()
ax.bar(avg_price_by_region.index, avg_price_by_region.values)
plt.xlabel('지역')
plt.ylabel('평균 거래 가격')
plt.show()


# 3. 거래 금액 분포
print('거래 금액 분포')
fig, ax = plt.subplots()
sns.histplot(df['dealAmount'], kde=True)
plt.xlabel('거래 금액')
plt.ylabel('빈도수')
plt.show()

# 추가적인 분석 및 시각화를 원하는 경우 여기에 추가
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/data/01_부동산/all_apartment_data(2023_2024_47).csv
# 데이터 정보
#   aptDong               aptNm  buildYear buyerGbn  cdealDay cdealType  \
# 0                       청호하이츠       1999           23.01.12         O
# 1                     이동현대홈타운       2000
# 2                          승리       1992
# 3          효자그린2차(현대,삼성그린APT)       1998
# 4                     포항자이아파트       2018
#
#   dealAmount  dealDay  dealMonth  dealYear  ... excluUseAr floor   jibun  \
# 0      4,350       24          1      2022  ...    36.0000     7   203-3
# 1     21,800       22          1      2022  ...    84.9936     5  469-14
# 2     30,700        8          1      2022  ...    83.0800     6   253-6
# 3     40,000       15          1      2022  ...    84.9700    13     946
# 4     53,000       31          1      2022  ...    84.9388    30    1036
#
# ...

# %%
# prompt: 한글이 꺠지네

from google.colab import drive
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import streamlit as st
drive.mount('/gdrive')
with open('/gdrive/My Drive/foo.txt', 'w') as f:
  f.write('Hello Google Drive!')
# !cat '/gdrive/My Drive/foo.txt'

# !pip install streamlit
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn


# Google Drive 마운트
drive.mount('/content/drive') # Google Drive 마운트를 확실하게 실행

# Google Drive에서 데이터 불러오기
data_path = '/content/drive/MyDrive/data/01_부동산/all_apartment_data(2023_2024_47).csv'
# 파일 경로가 정확한지 다시 한번 확인

# 파일 경로가 정확한지 확인하기 위해 출력해보기
print(data_path)

try:
    df = pd.read_csv(data_path)
except FileNotFoundError:
    print("파일을 찾을 수 없습니다. 파일 경로를 확인해주세요.")
    # st.stop() # 파일을 찾을 수 없으면 Streamlit 앱 실행 중지
except Exception as e:
    print(f"데이터를 불러오는 중 오류가 발생했습니다: {e}")
    # st.stop() # 다른 오류 발생 시에도 Streamlit 앱 실행 중지


# 데이터 정보 출력
print('데이터 정보')
print(df.head())
print(df.info())
print(df.describe())

# 시각화
print('데이터 시각화')


# 한글 폰트 설정 (Google Colab에서)
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

import matplotlib.font_manager as fm

fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=10)
plt.rc('font', family='NanumBarunGothic')
plt.rcParams['axes.unicode_minus'] = False


# 1. 지역별 평균 거래 가격
print('지역별 평균 거래 가격')
df['dealAmount'] = pd.to_numeric(df['dealAmount'].str.replace(',', ''), errors='coerce')

avg_price_by_region = df.groupby('sggCd')['dealAmount'].mean()
fig, ax = plt.subplots()
ax.bar(avg_price_by_region.index, avg_price_by_region.values)
plt.xlabel('지역')
plt.ylabel('평균 거래 가격')
plt.show()


# 3. 거래 금액 분포
print('거래 금액 분포')
fig, ax = plt.subplots()
sns.histplot(df['dealAmount'], kde=True)
plt.xlabel('거래 금액')
plt.ylabel('빈도수')
plt.show()

# 추가적인 분석 및 시각화를 원하는 경우 여기에 추가
# Out:
# Mounted at /gdrive
# Hello Google Drive!Mounted at /content/drive
# /content/drive/MyDrive/data/01_부동산/all_apartment_data(2023_2024_47).csv
# 데이터 정보
#   aptDong               aptNm  buildYear buyerGbn  cdealDay cdealType  \
# 0                       청호하이츠       1999           23.01.12         O
# 1                     이동현대홈타운       2000
# 2                          승리       1992
# 3          효자그린2차(현대,삼성그린APT)       1998
# 4                     포항자이아파트       2018
#
#   dealAmount  dealDay  dealMonth  dealYear  ... excluUseAr floor   jibun  \
# 0      4,350       24          1      2022  ...    36.0000     7   203-3
# 1     21,800       22          1      2022  ...    84.9936     5  469-14
# 2     30,700        8          1      2022  ...    83.0800     6   253-6
# 3     40,000       15          1      2022  ...    84.9700    13     946
# 4     53,000       31          1      2022  ...    84.9388    30    1036
#
# ...
